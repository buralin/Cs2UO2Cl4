# %% [markdown]
# # Report Pseudopotentials:
#
# ## Table of Contents:
#
# 1 [Aim](#aim)
#
# 2 [Performed Calculations](#Performed Calculations)
#
# 3 [Results](#results)

# %% [markdown]
# <div id='aim'/>
# ## Aim
#
# The aim of the following benchmarks is to verify the choice of the a Pseudopotential for a subsystem-DFT calculation of Cs<sub>2</sub>UO<sub>2</sub>Cl<sub>4</sub> to get the best possible embedding potential for the Uranyl-Ion in the crystal surrounding.
#
# <div id='Performed Calculations'/>
# ## Performed Calculations
#
# The following calculations were performed for Uranium in the orthorombic crystalsystem. The lattice constants were chosen from B. E. Warren et al. (*J. Am. Chem. Soc.*, 1937, 59 (12), pp 2588–2591):
#
# * a = 285.2 pm
# * b = 586.5 pm
# * c = 494.5 pm
#
# For the calculations the following programms were used:
#
# * Quantum Espresso (QE)
# * exciting
#
# For both programs only gamma-point is used for sampling the first Brillouin zone. All tested Pseudopotentials were generated with scalar relativistic calculation. In the case of exciting the calaculations were performed using "dirac" relativistic describing the core electrons and "zora" relativistic for the valence electrons.
#
# The following XC-Functionals were used:
#
# * PZ (QE/exciting)
# * PW (QE/exciting)
# * PBE (QE/exciting)
# * PBE-Sol (QE/exciting)
# * WC (QE/exciting)
# * BP (QE)
#
# Exact List of used Pseudopotentials Functionals (USPP: rrkjus/ PAW: kjpaw/ NC: Davide Ceresoli):
#
# * U.bp-spfn-kjpaw_psl.1.0.0.UPF
# * U.bp-spfn-rrkjus_psl.1.0.0.UPF
# * U.pbesol-spfn-kjpaw_psl.1.0.0.UPF
# * U.pbesol-spfn-rrkjus_psl.1.0.0.UPF
# * U.pbe-spfn-kjpaw_psl.1.0.0.UPF
# * U.pbe-spfn-rrkjus_psl.1.0.0.UPF
# * U.pbe-tm-gipaw-dc.UPF (NC from https://sites.google.com/site/dceresoli/pseudopotentials)
# * U.pw91-spfn-kjpaw_psl.1.0.0.UPF
# * U.pw91-spfn-rrkjus_psl.1.0.0.UPF
# * U.pz-spfn-kjpaw_psl.1.0.0.UPF
# * U.pz-spfn-rrkjus_psl.1.0.0.UPF
#
#
# * U.rel-bp-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-bp-spfn-rrkjus_psl.1.0.0.UPF
# * U.rel-pbesol-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-pbesol-spfn-rrkjus_psl.1.0.0.UPF
# * U.rel-pbe-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-pbe-spfn-rrkjus_psl.1.0.0.UPF
# * U.rel-pw91-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-pw91-spfn-rrkjus_psl.1.0.0.UPF
# * U.rel-pz-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-pz-spfn-rrkjus_psl.1.0.0.UPF
# * U.rel-wc-spfn-kjpaw_psl.1.0.0.UPF
# * U.rel-wc-spfn-rrkjus_psl.1.0.0.UPF
#
# For the QE calculations a cut-off Energy of 150 Ry were chosen and the Size of the cell were varied by a scalar (0.9 - 1.1) which was equal for all lattice constants and gaussian smearing was used with degauss = 0.4 Ry. The maximum amount of iterations for the scf was 200.

# %% [markdown]
# <div id='results'/>
# ## Results
#
# At first we can compare the convergence of the performed calculations (Pseudopotentials and scalars):
#
# * QE:
#
# | Pseudopotential  | 0.9 | 0.925 | 0.95 | 0.975 | 1 | 1.025 | 1.050 | 1.075 | 1.1 |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|:------:|
# |  U.bp-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
# | U.bp-spfn-rrkjus_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# |  U.pbesol-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.pbesol-spfn-rrkjus_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
# | U.pbe-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
# | U.pbe-spfn-rrkjus_psl.1.0.0.UPF| yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.pbe-tm-gipaw-dc.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.pw91-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> | yes |
# | U.pw91-spfn-rrkjus_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.pz-spfn-rrkjus_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> | <span style="color:red">no</span> |
# | U.pz-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | <span style="color:red">no</span> | <span style="color:red">no</span> | <span style="color:red">no</span> |
# | U.rel-bp-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-bp-spfn-rrkjus_psl.1.0.0.UPF | <span style="color:red">no</span> |  <span style="color:red">no</span> | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pbesol-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pbesol-spfn-rrkjus_psl.1.0.0.UPF | <span style="color:red">no</span> |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pbe-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pbe-spfn-rrkjus_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pw91-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pw91-spfn-rrkjus_psl.1.0.0.UPF | <span style="color:red">no</span> |  <span style="color:red">no</span> | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pz-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-pz-spfn-rrkjus_psl.1.0.0.UPF | <span style="color:red">no</span> |  <span style="color:red">no</span> | <span style="color:red">no</span> | <span style="color:red">no</span> | <span style="color:red">no</span> | <span style="color:red">no</span> | <span style="color:red">no</span> | yes | yes |
# | U.rel-wc-spfn-kjpaw_psl.1.0.0.UPF | yes |  yes | yes | yes | yes | yes | yes | yes | yes |
# | U.rel-wc-spfn-rrkjus_psl.1.0.0.UPF | <span style="color:red">no</span> |  <span style="color:red">no</span> | <span style="color:red">no</span> | yes | yes | yes | yes | yes | yes |
#
#
# * exciting:
#
# | XC-Functional  | 0.9 | 0.925 | 0.95 | 0.975 | 1 | 1.025 | 1.050 | 1.075 | 1.1 |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|:------:|
# | PW | <span style="color:red">no</span> | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> | <span style="color:red">no</span> |
# | PZ | <span style="color:red">no</span> |  yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> | <span style="color:red">no</span> |
# | PBE | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
# | PBE-Sol | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
# | WC | yes |  yes | yes | yes | yes | yes | yes | yes | <span style="color:red">no</span> |
#
#
# For the aim of this benchmark is to evaluate the best pseudopotential to use for the fde calculation of Cs<sub>2</sub>UO<sub>2</sub>Cl<sub>4</sub> with eQE. For this purpose only US or NC PP can be used because eQE isn't supporting PAW yet. This is the reason why only these types of PP are used in further considerations.

# %% [markdown]
# The evaluation of the results will be done below.
#
# ### Correlation Coefficients:
#
# The calculation of the correlation coefficents were performed using the numpy library and the reference is always the all electron calculation from exciting for the specific XC-Functional. In the following bar graphs $$ |\mathrm{log(1 - corr. coef.)}| $$ is shown for better visualisation.
#
# * PW:

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import math
 
objects = ('kjpaw', 'rrkjus', 'rel-kjpaw', 'rel-rrkjus')
y_pos = np.arange(len(objects))
corr = [(-1*math.log(1-0.999499448399)), (-1*math.log(1-0.999505790596)), (-1*math.log(1-0.999571543105)),(-1*math.log(1-0.999291696277))]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('|log(1-corr. coef.)|')
 
plt.show()

# %% [markdown]
# * PZ

# %%
objects = ('kjpaw', 'rrkjus', 'rel-kjpaw')
y_pos = np.arange(len(objects))
corr = [(-1*math.log(1-0.652600999738)), (-1*math.log(1-0.999428345353)), (-1*math.log(1-0.999512637058))]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('|log(1-corr. coef.)|')
 
plt.show()

# %% [markdown]
# * PBE:

# %%
objects = ('kjpaw', 'rrkjus', 'rel-kjpaw', 'rel-rrkjus', 'NC')
y_pos = np.arange(len(objects))
corr = [(-1*math.log(1-0.999463755775)),(-1*math.log(1-0.999470298965)), (-1*math.log(1-0.99958587683)), (-1*math.log(1-0.99958587683)),(-1*math.log(1-0.999319117723))]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('|log(1-corr. coef.)|')

plt.show()

# %% [markdown]
# * PBESOl

# %%
objects = ('kjpaw', 'rrkjus', 'rel-kjpaw', 'rel-rrkjus')
y_pos = np.arange(len(objects))
corr = [(-1*math.log(1-0.999491770287)),(-1*math.log(1-0.999497449747)),(-1*math.log(1-0.999616718043)),(-1*math.log(1-0.999616718043))]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('|log(1-corr. coef.)|')
 
plt.show()

# %% [markdown]
# * WC

# %%
objects = ('rel-kjpaw', 'rel-rrkjus')
y_pos = np.arange(len(objects))
corr = [(-1*math.log(1-0.99960645797)), (-1*math.log(1-0.99960645797))]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('|log(1-corr. coef.)|')
 
plt.show()

# %% [markdown]
# From the bar charts can be seen that the correlationcoefficients (except PZ-kjpaw) are all near 1. This means that the data from the exciting calculation and the data fom the QE calculation is nearly fully correlated. For the comparison between these different data sets it has to be taken into account that the calculated corr. coef. are based on different amounts of calculated scalars because not all calculations converged. It seems that the PBE calculations are the most reliable in the case of USPP. Even the NC PP (Davide Ceresoli) converged for all different scalars in the case of PBE.
#
# Furthermore correlation coeffients for the Pseudopotentials within the same XC-Functional were done too :

# %% [markdown]
# * PW
#
# | XC-Functional  | EX_PW | PW91_rrkjus | PW91_kjpaw | rel-PW91_rrkjus | rel-PW91_kjpaw |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|
# | EX_PW | 1.0 | 0.99950 | 0.99950 | 0.9996 | 0.9993 |
# | PW91_rrkjus| 0.99950  | 1.0 | 0.999999 | 0.99999|0.999999 |
# | PW91_kjpaw| 0.99950 | 0.999999 | 1.0 | | 0.99999 |
# | rel-PW91_rrkjus| 0.9996| 0.99999| | 1.0| 0.99999 |
# | rel-PW91_kjpaw| 0.9993 | 0.999999|0.99999| 0.99999| 1.0|

# %% [markdown]
#  * PZ
#
# | XC-Functional  | EX_PZ | PZ_rrkjus | PZ_kjpaw | rel-PZ_rrkjus | rel-PZ_kjpaw |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|
# | EX_PZ | 1.0 | 0.9994 | 0.65260 | x | 0.9995 |
# | PZ_rrkjus| 0.9994  | 1.0 | 0.9999 | x| 0.9999 |
# | PZ_kjpaw| 0.65260  | 0.9999 | 1.0 |x | 0.9999|
# | rel-PZ_rrkjus| x| x| x| 1.0| x |
# | rel-PZ_kjpaw| 0.9995 | 0.9999| 0.9999 |x | 1.0|

# %% [markdown]
# * PBE
#
#
# | XC-Functional  | EX_PBE | PBE_rrkjus | PBE_kjpaw | rel-PBE_rrkjus | rel-PBE_kjpaw | pbe-NC |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|
# | EX_PBE | 1.0 | 0.9994 | 0.9994 | 0.9995 | 0.9995 |0.9993 |
# | PBE_rrkjus| 0.9994  | 1.0 | 0.9999 | 0.9999 | 0.9999 |0.9999|
# | PBE_kjpaw| 0.9994  | 0.9999 | 1.0 | 0.9999 | 0.9999| 0.9999|
# | rel-PBE_rrkjus| 0.9995| 0.9999 | 0.9999 | 1.0| 0.9999 | 0.9999 |
# | rel-PBE_kjpaw| 0.9995 | 0.9999| 0.9999 |0.9999| 1.0|0.9999|
# | pbe-NC | 0.9993|0.9999 | 0.9999|0.9999 |0.9999 | 1.0|

# %% [markdown]
#  * PBESOL
#
# | XC-Functional  | EX_PBESOL | PBESOL_rrkjus | PBESOL_kjpaw | rel-PBESOL_rrkjus | rel-PBESOL_kjpaw |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:||:-------------:|
# | EX_PBESOL | 1.0 | 0.9995 | 0.9995 | 0.9996 | 0.9996 |
# | PBESOL_rrkjus|0.9995 | 1.0 | 0.9999 | 0.9999 | 0.9999 |
# | PBESOL_kjpaw| 0.9995 | 0.9999 | 1.0 | 0.9999 | 0.9999|
# | rel-PBESOL_rrkjus| 0.9996 | 0.9999 | 0.9999 | 1.0| 0.9999 |
# | rel-PBESOL_kjpaw| 0.9996 | 0.9999|0.9999 | 0.9999| 1.0|

# %% [markdown]
# * WC
#
# | XC-Functional  | EX_PBESOL | rel-PBESOL_rrkjus | rel-PBESOL_kjpaw |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:|
# | EX_PBESOL | 1.0 | 0.9992 | 0.9996 |
# | rel-PBESOL_rrkjus| 0.9992 | 1.0 | 0.9999|
# | rel-PBESOL_kjpaw| 0.9996 | 0.9999| 1.0 |

# %% [markdown]
# As a last step the correlationcoefficient of the different XC-Functionals were compared to figure out difference between these methods.
#
# | XC-Functional  | LDA_PW | LDA_PZ | GGA_PBE | GGA_PBESOL | GGA_WC |
# |----------|:-------------:||:-------------:||:-------------:||:-------------:|
# | LDA_PW |  1.0 | 0.9999 | 0.9999 | 0.9999 | 0.9999 |
# | LDA_WZ | 0.9999 | 1 | 0.9999 | 0.9999 | 0.9999 |
# | GGA_PBE | 0.9999 | 0.9999 | 1 | 0.9999 | 0.9999 |
# | GGA_PBESOL |0.9999 | 0.9999 | 0.9999 | 1 | 0.9999 |
# | GGA_WC |0.9999 | 0.9999 | 0.9999 | 0.9999 | 1 |
#
# As you can see these were also fully correlated.

# %% [markdown]
# ### Convergence
#
# Below is the convergence for the different XC-Functionals shown. It hast to be calirified that in the case of WC and the NC-PBE PP only half of the calculations are taken into account because NC is only available with scalar relativistic and WC is only available with full relativistic. In the case of PBE every calculation (NC and US) converged completely that justify the use of pbe for further inverstigations of Cs<sub>2</sub>UO<sub>2</sub>Cl<sub>4</sub>.

# %%
objects = ('PW91', 'PZ', 'PBE', 'PBE-SOL', 'BP', 'NC', 'WC')
y_pos = np.arange(len(objects))
corr = [(16/18)*100, (9/18)*100,(18/18)*100,(16/18)*100,(16/18)*100,(9/9)*100,(5/9)*100]
 
plt.bar(y_pos, corr, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('total convergence / %')
 
plt.show()
